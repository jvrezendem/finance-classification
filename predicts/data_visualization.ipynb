# %%
import pandas as pd
from pathlib import Path

BASE_DIR = Path("../data/outputs")
dataset_path =BASE_DIR / "result_test.csv"

df = pd.read_csv(dataset_path)

df.head(10)
# Out:
#          date                                    description_raw  \
# 0  2026-07-01  400,00 (+) 71493 879671493190456 Dep dinheiro ...
# 1  2026-07-06  1.000,00 (+) 75634 879675634190644 Dep dinheir...
# 2  2026-07-06  400,00 (-) 13105 70601 Pix - Enviado 04/07 11:...
# 3  2026-07-08  629,00 (-) 13105 70801 Pix - Enviado 08/07 20:...
# 4  2026-07-08  221,00 (-) 13105 70802 Pix - Enviado 08/07 20:...
# 5  2026-07-14  93,50 (+) 14397 142250094869771 Pix - Recebido...
# 6  2026-07-14  93,50 (-) 13105 71401 Pix - Enviado 14/07 22:0...
# 7  2026-07-15  133,85 (-) 13105 71501 Pix - Enviado 15/07 14:...
# 8  2026-07-15  16,15 (-) 13105 71502 Pix - Enviado 15/07 14:1...
# 9  2026-07-15  0,00 (+) 13105 71502 Pix - Enviado 15/07 14:11...
#
#                               description_normalized  amount_cents  \
# 0       Dep dinheiro ATM 01/07 19:04 SOP-DIVINOPOLIS         40000
# 1       Dep dinheiro ATM 06/07 19:06 SOP-DIVINOPOLIS        100000
# 2  Pix - Enviado 04/07 11:22 JOAO VITOR REZENDE M...        -40000
# 3  Pix - Enviado 08/07 20:42 JOAO EDUARDO JULIO C...        -62900
# 4  Pix - Enviado 08/07 20:48 JOAO VITOR REZENDE M...        -22100
# 5  Pix - Recebido 14/07 22:50 14461041689 JOAO VI...          9350
# 6  Pix - Enviado 14/07 22:03 LA PASTA RESTAURANTE...         -9350
# 7  Pix - Enviado 15/07 14:11 JOAO EDUARDO JULIO C...        -13385
# 8  Pix - Enviado 15/07 14:11 JOAO VITOR REZENDE M...         -1615
# 9  Pix - Enviado 15/07 14:11 JOAO VITOR REZENDE M...             0
#
#    signed_amount_cents direction transaction_type  balance_after_cents  \
# 0                40000    credit         deposito                40000
# 1               100000    credit         deposito               140000
# 2               -40000     debit              pix               100000
# 3               -62900     debit              pix                37000
# 4               -22100     debit              pix                15000
# 5                 9350    credit              pix                24150
# 6                -9350     debit              pix                14800
# 7               -13385     debit              pix                11415
# 8                -1615     debit              pix                 9800
# 9                    0    credit              pix                 9800
#
#         doc_number  transaction_code  source_page  \
# 0  879671493190456             71493            1
# 1  879675634190644             75634            1
# 2            70601             13105            1
# 3            70801             13105            1
# 4            70802             13105            1
# 5  142250094869771             14397            1
# 6            71401             13105            1
# 7            71501             13105            1
# 8            71502             13105            1
# 9            71502             13105            1
#
#                                          source_text extraction_method  \
# 0  400,00 (+) 71493 879671493190456 Dep dinheiro ...               llm
# 1  1.000,00 (+) 75634 879675634190644 Dep dinheir...               llm
# 2  400,00 (-) 13105 70601 Pix - Enviado 04/07 11:...               llm
# 3  629,00 (-) 13105 70801 Pix - Enviado 08/07 20:...               llm
# 4  221,00 (-) 13105 70802 Pix - Enviado 08/07 20:...               llm
# 5  93,50 (+) 14397 142250094869771 Pix - Recebido...               llm
# 6  93,50 (-) 13105 71401 Pix - Enviado 14/07 22:0...               llm
# 7  133,85 (-) 13105 71501 Pix - Enviado 15/07 14:...               llm
# 8  16,15 (-) 13105 71502 Pix - Enviado 15/07 14:1...               llm
# 9  0,00 (+) 13105 71502 Pix - Enviado 15/07 14:11...               llm
#
#    warnings  review_required
# 0       NaN            False
# 1       NaN            False
# 2       NaN            False
# 3       NaN            False
# 4       NaN            False
# 5       NaN            False
# 6       NaN            False
# 7       NaN            False
# 8       NaN            False
# 9       NaN            False

# %%
import pandas as pd
from pathlib import Path

BASE_DIR = Path("../data/outputs")
dataset_path =BASE_DIR / "result_test_500_ficticias.csv"

df = pd.read_csv(dataset_path)

df.head(500)
# Out:
#            date                                    description_raw  \
# 0    2025-01-01  1.548,85 (+) 64207 700000000000163 Dep dinheir...
# 1    2025-01-02  94,23 (-) 13015 700000000001154 Pix - Enviado ...
# 2    2025-01-03  373,74 (-) 53369 700000000002066 Pix - Enviado...
# 3    2025-01-05  558,20 (-) 69535 700000000003755 Pix - Enviado...
# 4    2025-01-06  708,13 (-) 22742 700000000004844 Pix - Enviado...
# ..          ...                                                ...
# 495  2026-12-19  657,49 (-) 79059 700000000493616 Pix - Enviado...
# 496  2026-12-21  611,07 (+) 30250 700000000495025 Transferência...
# 497  2026-12-22  2.125,32 (+) 98427 700000000496366 Transferênc...
# 498  2026-12-24  79,05 (-) 89607 700000000497193 Pix - Enviado ...
# 499  2026-12-25  55,26 (-) 42157 700000000497742 Pix - Enviado ...
#
#                                 description_normalized  amount_cents  \
# 0                  Dep dinheiro ATM 01/01 12:50 CENTRO        154885
# 1       Pix - Enviado 02/01 16:58 MANUTENÇÃO E OFICINA         -9423
# 2    Pix - Enviado 03/01 11:27 PARCELA DE FINANCIAM...        -37374
# 3         Pix - Enviado 05/01 07:27 PAGAMENTO DE MULTA        -55820
# 4       Pix - Enviado 06/01 22:43 MANUTENÇÃO E OFICINA        -70813
# ..                                                 ...           ...
# 495     Pix - Enviado 19/12 18:24 MANUTENÇÃO E OFICINA        -65749
# 496  Transferência recebida 21/12 18:31 PAGAMENTO D...         61107
# 497  Transferência recebida 22/12 11:40 PAGAMENTO D...        212532
# 498        Pix - Enviado 24/12 21:48 PAGAMENTO DE IPVA         -7905
# 499        Pix - Enviado 25/12 18:48 PARCELA DE SEGURO         -5526
#
#      signed_amount_cents direction transaction_type  balance_after_cents  \
# 0                 154885    credit         deposito               404885
# 1                  -9423     debit              pix               395462
# 2                 -37374     debit              pix               358088
# 3                 -55820     debit              pix               302268
# 4                 -70813     debit              pix               231455
# ..                   ...       ...              ...                  ...
# 495               -65749     debit              pix                36567
# 496                61107    credit    transferencia                97674
# 497               212532    credit    transferencia               310206
# 498                -7905     debit              pix               302301
# 499                -5526     debit              pix               296775
#
#           doc_number  transaction_code  source_page  \
# 0    700000000000163             64207            1
# 1    700000000001154             13015            1
# 2    700000000002066             53369            1
# 3    700000000003755             69535            1
# 4    700000000004844             22742            1
# ..               ...               ...          ...
# 495  700000000493616             79059           15
# 496  700000000495025             30250           15
# 497  700000000496366             98427           15
# 498  700000000497193             89607           15
# 499  700000000497742             42157           15
#
#                                            source_text extraction_method  \
# 0    1.548,85 (+) 64207 700000000000163 Dep dinheir...         synthetic
# 1    94,23 (-) 13015 700000000001154 Pix - Enviado ...         synthetic
# 2    373,74 (-) 53369 700000000002066 Pix - Enviado...         synthetic
# 3    558,20 (-) 69535 700000000003755 Pix - Enviado...         synthetic
# 4    708,13 (-) 22742 700000000004844 Pix - Enviado...         synthetic
# ..                                                 ...               ...
# 495  657,49 (-) 79059 700000000493616 Pix - Enviado...         synthetic
# 496  611,07 (+) 30250 700000000495025 Transferência...         synthetic
# 497  2.125,32 (+) 98427 700000000496366 Transferênc...         synthetic
# 498  79,05 (-) 89607 700000000497193 Pix - Enviado ...         synthetic
# 499  55,26 (-) 42157 700000000497742 Pix - Enviado ...         synthetic
#
#      warnings  review_required       category
# 0         NaN            False       deposito
# 1         NaN            False     manutenção
# 2         NaN            False  financeamento
# 3         NaN            False         multas
# 4         NaN            False     manutenção
# ..        ...              ...            ...
# 495       NaN            False     manutenção
# 496       NaN            False      oagamento
# 497       NaN            False      oagamento
# 498       NaN            False           ipva
# 499       NaN            False         seguro
#
# [500 rows x 16 columns]
